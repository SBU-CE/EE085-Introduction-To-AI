# %% [markdown]
# Matplotlib:

# %%
pip install matplotlib

# %%
import matplotlib

# %%
print(matplotlib.__version__)
# Out:
# 3.7.1

# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,6])
ypoints = np.array([0,200])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,6])
ypoints = np.array([0,200])
plt.plot(xpoints, ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,6,10,8])
ypoints = np.array([0,200,30,20])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([0,200,30,20])
plt.plot(ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,1,2,3])
ypoints = np.array([0,200,30,20])
plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,1,2,3])
ypoints = np.array([0,200,30,20])
plt.plot(xpoints, ypoints, marker = 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,1,2,3])
ypoints = np.array([0,200,30,20])
plt.plot(xpoints, ypoints, marker = '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,1,2,3])
ypoints = np.array([0,200,30,20])
plt.plot(xpoints, ypoints, 'o:r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
xpoints = np.array([0,1,2,3])
ypoints = np.array([0,200,30,20])
plt.plot(xpoints, ypoints, 'o--b')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([0,200,30,20])
plt.plot(ypoints, marker = 'o', ms = 15)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([0,200,30,20])
plt.plot(ypoints, marker = 'o', ms = 15, mec = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([0,200,30,20])
plt.plot(ypoints, marker = 'o', ms = 15, mfc = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([0,200,30,20])
plt.plot(ypoints, marker = 'o', ms = 15 , mec = 'r', mfc = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([0,200,30,20])
plt.plot(ypoints, marker = 'o', ms = 15 , mec = '#4CAF50', mfc = '#4CAF90')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([0,200,30,20])
plt.plot(ypoints, marker = 'o', ms = 15 , mec = 'hotpink', mfc = 'hotpink')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([0,200,30,20])
plt.plot(ypoints, linestyle = 'dotted')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([0,200,30,20])
plt.plot(ypoints, linestyle = 'dashed')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([0,200,30,20])
plt.plot(ypoints, ls = '--')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([0,200,30,20])
plt.plot(ypoints, color = 'r')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([0,200,30,20])
plt.plot(ypoints, linewidth = '15')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([0,200,30,20])
plt.plot(ypoints, lw = '15')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y1 = np.array([0,200,30,20])
y2 = np.array([0,100,50,70])
plt.plot(y1)
plt.plot(y2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320,330])
plt.plot(x, y)
plt.xlabel("Average Pulse")
plt.ylabel("Calories Burnage")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320,330])
plt.plot(x, y)
plt.title("Sports Watch Data")
plt.xlabel("Average Pulse")
plt.ylabel("Calories Burnage")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320,330])
font1 = {'family': 'serif', 'color': 'blue', 'size' : '20'}
plt.plot(x, y)
plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse")
plt.ylabel("Calories Burnage")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320,330])
font1 = {'family': 'serif', 'color': 'blue', 'size' : '20'}
plt.plot(x, y)
plt.title("Sports Watch Data", fontdict = font1, loc = 'left')
plt.xlabel("Average Pulse")
plt.ylabel("Calories Burnage")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320,330])
font1 = {'family': 'serif', 'color': 'blue', 'size' : '20'}
plt.plot(x, y)
plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse")
plt.ylabel("Calories Burnage")
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320,330])
font1 = {'family': 'serif', 'color': 'blue', 'size' : '20'}
plt.plot(x, y)
plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse")
plt.ylabel("Calories Burnage")
plt.grid(axis = 'x')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320,330])
font1 = {'family': 'serif', 'color': 'blue', 'size' : '20'}
plt.plot(x, y)
plt.title("Sports Watch Data", fontdict = font1)
plt.xlabel("Average Pulse")
plt.ylabel("Calories Burnage")
plt.grid(color = 'red', linestyle = '--', linewidth = 0.5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320,330])
font1 = {'family': 'serif', 'color': 'blue', 'size' : '20'}
plt.subplot(1, 2, 1)
plt.plot(x, y)
x = np.array([70, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 200, 310, 320,330])
plt.subplot(1, 2, 2)
plt.plot(x, y)
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320,330])
font1 = {'family': 'serif', 'color': 'blue', 'size' : '20'}
plt.subplot(2, 1, 1)
plt.plot(x, y)
x = np.array([70, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 200, 310, 320,330])
plt.subplot(2, 1, 2)
plt.plot(x, y)
plt.grid()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320,330])
font1 = {'family': 'serif', 'color': 'blue', 'size' : '20'}
plt.subplot(1, 2, 1)
plt.plot(x, y)
plt.title("Sales")
x = np.array([70, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 200, 310, 320,330])
plt.subplot(1, 2, 2)
plt.plot(x, y)
plt.title("Income")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320,330])
font1 = {'family': 'serif', 'color': 'blue', 'size' : '20'}
plt.subplot(1, 2, 1)
plt.plot(x, y)
plt.title("Sales")
x = np.array([70, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 200, 310, 320,330])
plt.subplot(1, 2, 2)
plt.plot(x, y)
plt.title("Income")
plt.suptitle("Shop")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320,330])
plt.scatter(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320,330])
plt.scatter(x, y)
x = np.array([70, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 200, 310, 320,330])
plt.scatter(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320,330])
plt.scatter(x, y, color = 'red')
x = np.array([70, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 200, 310, 320,330])
plt.scatter(x, y, color = 'blue')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95])
y = np.array([240, 250, 260, 270])
colors = np.array(["red", "blue", "green", "yellow"])
plt.scatter(x, y, c=colors)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95])
y = np.array([240, 250, 260, 270])
colors = np.array([0, 10, 50, 90])
plt.scatter(x, y, c=colors, cmap = 'viridis')
plt.colorbar()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95])
y = np.array([240, 250, 260, 270])
colors = np.array([0, 10, 50, 90])
plt.scatter(x, y, c=colors, cmap = 'viridis_r')
plt.colorbar()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95])
y = np.array([240, 250, 260, 270])
colors = np.array([0, 10, 50, 90])
sizes = np.array([20, 50, 100, 200])
plt.scatter(x, y, c=colors, cmap = 'viridis', s=sizes)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([80, 85, 90, 95])
y = np.array([240, 250, 260, 270])
colors = np.array([0, 10, 50, 90])
sizes = np.array([20, 50, 100, 200])
plt.scatter(x, y, c=colors, cmap = 'viridis', s=sizes, alpha = 0.5)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
x = np.random.randint(100, size = (100))
y = np.random.randint(100, size = (100))
colors = np.random.randint(100, size = (100))
sizes = 10*np.random.randint(100, size = (100))
plt.scatter(x, y, c=colors, s=sizes, alpha=0.5,cmap='nipy_spectral')
plt.colorbar()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 6, 9, 10])
plt.bar(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 6, 9, 10])
plt.barh(x, y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 6, 9, 10])
plt.bar(x, y, color = "red")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 6, 9, 10])
plt.bar(x, y, color = 'blue', width = 0.2)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 6, 9, 10])
plt.barh(x, y, color = 'blue', height = 0.2)
plt.show()

# %%
import numpy as np
x = np.random.normal(170, 10, 250)
print(x)
# Out:
# [188.24053548 171.84087311 171.15221362 177.87979982 201.96590294
#  166.4834127  163.09278096 160.17197212 167.19144657 170.83075384
#  179.41132693 170.29352162 158.75828927 170.10730248 176.61617284
#  186.40088141 164.67873034 167.61484963 155.90793363 165.05797101
#  152.72779595 188.72499347 160.02199516 155.20602136 183.4199142
#  173.88649912 162.56786555 162.70282351 200.14947883 159.85117928
#  173.39727207 157.32055412 161.91112697 205.34214153 172.13409802
#  165.30835974 167.78101223 177.79183635 177.70794368 169.3565206
#  179.47977393 173.65594207 165.09313404 182.96375862 170.34738945
#  169.3122523  170.76348609 153.95484674 163.71225372 170.94864217
#  162.11278184 190.91510107 185.39077723 168.94013006 166.47150333
#  159.32326146 153.33075839 167.95745505 165.9009748  174.60857458
#  165.61303801 164.85279331 183.75057007 162.35149726 168.43660422
#  199.25305663 159.53344116 176.60759248 161.78495344 161.14184888
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.random.normal(170, 10, 250)
plt.hist(x)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 20, 5, 15])
plt.pie(y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 20, 5, 15])
plt.pie(y, startangle = 90)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 20, 5, 15])
mylables = ["X", "Y", "Z", "T"]
myexplodes = [0.2, 0, 0, 0]
plt.pie(y, labels = mylables, explode = myexplodes)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 20, 5, 15])
mylables = ["X", "Y", "Z", "T"]
myexplodes = [0.2, 0, 0, 0]
plt.pie(y, labels = mylables, explode = myexplodes, shadow = "True")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 20, 5, 15])
mylables = ["X", "Y", "Z", "T"]
myexplodes = [0.2, 0, 0, 0]
plt.pie(y, labels = mylables, explode = myexplodes)
plt.legend()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 20, 5, 15])
mylables = ["X", "Y", "Z", "T"]
myexplodes = [0.2, 0, 0, 0]
plt.pie(y, labels = mylables, explode = myexplodes)
plt.legend(title = "Four Fruits")
plt.show()
